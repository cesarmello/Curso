# %%
import pandas as pd

df1 = pd.DataFrame({'A': [4, 2, 1, 3], 'B': ['a', 'b', 'c', 'b']})
df2 = pd.DataFrame({'A': [2, 3, 5], 'C': [10, 20, 30]})


df1
# Out:
#    A  B
# 0  4  a
# 1  2  b
# 2  1  c
# 3  3  b

# %%
df2
# Out:
#    A   C
# 0  2  10
# 1  3  20
# 2  5  30

# %%
df1.merge(df2,on='A',how='left')
# Out:
#    A  B     C
# 0  4  a   NaN
# 1  2  b  10.0
# 2  1  c   NaN
# 3  3  b  20.0

# %%
df1.merge(df2,on='A',how='right')
# Out:
#    A    B   C
# 0  2    b  10
# 1  3    b  20
# 2  5  NaN  30

# %%
df1.merge(df2,on='A',how='inner')
# Out:
#    A  B   C
# 0  2  b  10
# 1  3  b  20

# %%
df1.merge(df2,on='A',how='outer')
# Out:
#    A    B     C
# 0  1    c   NaN
# 1  2    b  10.0
# 2  3    b  20.0
# 3  4    a   NaN
# 4  5  NaN  30.0

# %%
df1.sort_values('A').reset_index(drop=True)
# Out:
#    A  B
# 0  1  c
# 1  2  b
# 2  3  b
# 3  4  a

# %%
df3 = pd.concat([df1,df2], ignore_index = True)

df3
# Out:
#    A    B     C
# 0  4    a   NaN
# 1  2    b   NaN
# 2  1    c   NaN
# 3  3    b   NaN
# 4  2  NaN  10.0
# 5  3  NaN  20.0
# 6  5  NaN  30.0

# %%
todas = pd.concat([df1,df2], axis=1)
# Out:
#    A  B    A     C
# 0  4  a  2.0  10.0
# 1  2  b  3.0  20.0
# 2  1  c  5.0  30.0
# 3  3  b  NaN   NaN

# %%
df1.groupby('B').sum().reset_index()
# Out:
#    B  A
# 0  a  4
# 1  b  5
# 2  c  1
